# %%
import xarray as xr

# %%
file = "../data/outputs/out-om-domain-info.nc"

dataset = xr.open_dataset(file)

# %%
dataset
# Out:
# <xarray.Dataset> Size: 23MB
# Dimensions:           (TSTEP: 1, ROW: 430, COL: 454, LAY: 1, ROW_D: 431,
#                        COL_D: 455, date: 1, y: 430, x: 454)
# Coordinates:
#   * LAY               (LAY) int64 8B 1
#   * date              (date) datetime64[ns] 8B 2022-07-01
#   * y                 (y) int64 3kB 0 1 2 3 4 5 6 ... 424 425 426 427 428 429
#   * x                 (x) int64 4kB 0 1 2 3 4 5 6 ... 448 449 450 451 452 453
# Dimensions without coordinates: TSTEP, ROW, COL, ROW_D, COL_D
# Data variables: (12/18)
#     LAT               (TSTEP, ROW, COL) float32 781kB ...
#     LON               (TSTEP, ROW, COL) float32 781kB ...
#     LANDMASK          (TSTEP, ROW, COL) float32 781kB ...
#     LATD              (TSTEP, LAY, ROW_D, COL_D) float32 784kB ...
#     LOND              (TSTEP, LAY, ROW_D, COL_D) float32 784kB ...
#     OCH4_AGRICULTURE  (TSTEP, LAY, ROW, COL) float64 2MB ...
#     ...                ...
# ...
